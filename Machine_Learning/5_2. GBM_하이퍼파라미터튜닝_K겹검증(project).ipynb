# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score
from sklearn.metrics import mean_absolute_error
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from IPython.display import Image

# %%
car = pd.read_csv('./car_price_remove_one_hot_encoding.csv')

# %%
car
# Out:
#       price  brand_hyundai  model_grandeur  model_grandeurHG  \
# 0      1999           True           False             False
# 1      2489           True           False             False
# 2      2950           True           False             False
# 3      1540           True           False             False
# 4      2400           True           False             False
# ...     ...            ...             ...               ...
# 1305    550           True           False              True
# 1306    689           True           False              True
# 1307   1650           True           False             False
# 1308    800           True           False              True
# 1309   1470           True           False             False
#
#       model_grandeurHG_hybrid  model_grandeurTG  model_grandeur_GN7  \
# 0                       False             False               False
# 1                       False             False               False
# 2                       False             False                True
# 3                       False             False               False
# 4                       False             False               False
# ...                       ...               ...                 ...
# 1305                    False             False               False
# 1306                    False             False               False
# 1307                    False             False               False
# 1308                    False             False               False
# 1309                    False             False               False
#
#       model_grandeur_IG  model_grandeur_IG_hybrid  model_grandeur_hybrid_GN7  \
# 0                 False                     False                      False
# 1                 False                     False                      False
# 2                 False                     False                      False
# 3                 False                      True                      False
# 4                 False                     False                      False
# ...                 ...                       ...                        ...
# 1305              False                     False                      False
# 1306              False                     False                      False
# 1307               True                     False                      False
# 1308              False                     False                      False
# 1309               True                     False                      False
#
#       ...  mileage_100001_110000  mileage_110001_120000  \
# 0     ...                  False                   True
# 1     ...                  False                  False
# 2     ...                  False                  False
# 3     ...                  False                  False
# 4     ...                  False                  False
# ...   ...                    ...                    ...
# 1305  ...                  False                  False
# 1306  ...                  False                  False
# 1307  ...                  False                  False
# 1308  ...                  False                  False
# 1309  ...                  False                   True
#
#       mileage_120001_130000  mileage_130001_140000  mileage_140001_150000  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                      True                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 1305                  False                  False                   True
# 1306                  False                  False                  False
# 1307                  False                  False                  False
# 1308                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_150001_160000  mileage_160001_170000  mileage_170001_180000  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 1305                  False                  False                  False
# 1306                  False                  False                  False
# 1307                  False                  False                  False
# 1308                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_180001_190000  mileage_190001_200000
# 0                     False                  False
# 1                     False                  False
# 2                     False                  False
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 1305                  False                  False
# 1306                  False                  False
# 1307                  False                  False
# 1308                   True                  False
# 1309                  False                  False
#
# [1310 rows x 62 columns]

# %% [markdown]
# ### 변수
# - brand
# - model
# - year
# - price
# - transmission
# - mileage
# - fuelType
# - mpg
# - engineSize

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 62 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   price                             1310 non-null   int64
#  1   brand_hyundai                     1310 non-null   bool
#  2   model_grandeur                    1310 non-null   bool
#  3   model_grandeurHG                  1310 non-null   bool
#  4   model_grandeurHG_hybrid           1310 non-null   bool
#  5   model_grandeurTG                  1310 non-null   bool
#  6   model_grandeur_GN7                1310 non-null   bool
#  7   model_grandeur_IG                 1310 non-null   bool
#  8   model_grandeur_IG_hybrid          1310 non-null   bool
#  9   model_grandeur_hybrid_GN7         1310 non-null   bool
#  10  model_grandeur_new_luxury         1310 non-null   bool
#  11  model_new_grandeur                1310 non-null   bool
#  12  model_the_luxury_grandeur         1310 non-null   bool
#  13  model_the_new_grandeur_IG         1310 non-null   bool
#  14  model_the_new_grandeur_IG_hybrid  1310 non-null   bool
#  15  year_1992                         1310 non-null   bool
#  16  year_1994                         1310 non-null   bool
#  17  year_2006                         1310 non-null   bool
#  18  year_2007                         1310 non-null   bool
#  19  year_2008                         1310 non-null   bool
#  20  year_2009                         1310 non-null   bool
#  21  year_2010                         1310 non-null   bool
#  22  year_2011                         1310 non-null   bool
#  23  year_2012                         1310 non-null   bool
#  24  year_2013                         1310 non-null   bool
#  25  year_2014                         1310 non-null   bool
#  26  year_2015                         1310 non-null   bool
#  27  year_2016                         1310 non-null   bool
#  28  year_2017                         1310 non-null   bool
#  29  year_2018                         1310 non-null   bool
#  30  year_2019                         1310 non-null   bool
#  31  year_2020                         1310 non-null   bool
#  32  year_2021                         1310 non-null   bool
#  33  year_2022                         1310 non-null   bool
#  34  year_2023                         1310 non-null   bool
#  35  year_2024                         1310 non-null   bool
#  36  year_2025                         1310 non-null   bool
#  37  year_2026                         1310 non-null   bool
#  38  oilingtype_LPG                    1310 non-null   bool
#  39  oilingtype_diesel                 1310 non-null   bool
#  40  oilingtype_gasoline               1310 non-null   bool
#  41  oilingtype_hybrid                 1310 non-null   bool
#  42  mileage_0_10000                   1310 non-null   bool
#  43  mileage_10001_20000               1310 non-null   bool
#  44  mileage_20001_30000               1310 non-null   bool
#  45  mileage_30001_40000               1310 non-null   bool
#  46  mileage_40001_50000               1310 non-null   bool
#  47  mileage_50001_60000               1310 non-null   bool
#  48  mileage_60001_70000               1310 non-null   bool
#  49  mileage_70001_80000               1310 non-null   bool
#  50  mileage_80001_90000               1310 non-null   bool
#  51  mileage_90001_100000              1310 non-null   bool
#  52  mileage_100001_110000             1310 non-null   bool
#  53  mileage_110001_120000             1310 non-null   bool
#  54  mileage_120001_130000             1310 non-null   bool
#  55  mileage_130001_140000             1310 non-null   bool
#  56  mileage_140001_150000             1310 non-null   bool
#  57  mileage_150001_160000             1310 non-null   bool
#  58  mileage_160001_170000             1310 non-null   bool
#  59  mileage_170001_180000             1310 non-null   bool
#  60  mileage_180001_190000             1310 non-null   bool
#  61  mileage_190001_200000             1310 non-null   bool
# dtypes: bool(61), int64(1)
# memory usage: 88.4 KB

# %%
car
# Out:
#       price  brand_hyundai  model_grandeur  model_grandeurHG  \
# 0      1999           True           False             False
# 1      2489           True           False             False
# 2      2950           True           False             False
# 3      1540           True           False             False
# 4      2400           True           False             False
# ...     ...            ...             ...               ...
# 1305    550           True           False              True
# 1306    689           True           False              True
# 1307   1650           True           False             False
# 1308    800           True           False              True
# 1309   1470           True           False             False
#
#       model_grandeurHG_hybrid  model_grandeurTG  model_grandeur_GN7  \
# 0                       False             False               False
# 1                       False             False               False
# 2                       False             False                True
# 3                       False             False               False
# 4                       False             False               False
# ...                       ...               ...                 ...
# 1305                    False             False               False
# 1306                    False             False               False
# 1307                    False             False               False
# 1308                    False             False               False
# 1309                    False             False               False
#
#       model_grandeur_IG  model_grandeur_IG_hybrid  model_grandeur_hybrid_GN7  \
# 0                 False                     False                      False
# 1                 False                     False                      False
# 2                 False                     False                      False
# 3                 False                      True                      False
# 4                 False                     False                      False
# ...                 ...                       ...                        ...
# 1305              False                     False                      False
# 1306              False                     False                      False
# 1307               True                     False                      False
# 1308              False                     False                      False
# 1309               True                     False                      False
#
#       ...  mileage_100001_110000  mileage_110001_120000  \
# 0     ...                  False                   True
# 1     ...                  False                  False
# 2     ...                  False                  False
# 3     ...                  False                  False
# 4     ...                  False                  False
# ...   ...                    ...                    ...
# 1305  ...                  False                  False
# 1306  ...                  False                  False
# 1307  ...                  False                  False
# 1308  ...                  False                  False
# 1309  ...                  False                   True
#
#       mileage_120001_130000  mileage_130001_140000  mileage_140001_150000  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                      True                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 1305                  False                  False                   True
# 1306                  False                  False                  False
# 1307                  False                  False                  False
# 1308                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_150001_160000  mileage_160001_170000  mileage_170001_180000  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 1305                  False                  False                  False
# 1306                  False                  False                  False
# 1307                  False                  False                  False
# 1308                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_180001_190000  mileage_190001_200000
# 0                     False                  False
# 1                     False                  False
# 2                     False                  False
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 1305                  False                  False
# 1306                  False                  False
# 1307                  False                  False
# 1308                   True                  False
# 1309                  False                  False
#
# [1310 rows x 62 columns]

# %% [markdown]
# ### train/test 셋 분리

# %%
x = car.drop("price", axis = 1)
y = car["price"]

# %%
# 기본값은 70 : 30 비율
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.70, random_state=1)

# %%
x_train.shape, y_train.shape
# Out:
# ((916, 61), (916,))

# %%
x_test.shape, y_test.shape
# Out:
# ((394, 61), (394,))

# %% [markdown]
# ### 경사부스팅

# %%
y_prime = y_train

y_prime
# Out:
# 527     1999
# 993     2150
# 1153    3460
# 1060    1850
# 372     2980
#         ...
# 715     2420
# 905     3200
# 1096    3515
# 235     1620
# 1061    3590
# Name: price, Length: 916, dtype: int64

# %%
y_test_prime = y_test

y_test_prime
# Out:
# 201     1520
# 115     2240
# 255     3790
# 1104     790
# 195     2670
#         ...
# 1035    2710
# 180      800
# 191     2429
# 348     2450
# 306      535
# Name: price, Length: 394, dtype: int64

# %%
param_grid ={  }

# %%
param_grid
# Out:
# {}

# %%
grid_search = GridSearchCV(GradientBoostingRegressor(loss= 'huber'),
                           param_grid, cv=3, return_train_score=True)

# %%
grid_search.fit(x_train, y_prime)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={}, return_train_score=True)

# %%
y_pred = grid_search.predict(x_test) #예축값 
y_pred
# Out:
# array([1544.86623309, 2380.52525526, 3448.58330593,  972.31590679,
#        2249.11379342, 2479.97457504,  717.30580984, 3533.03000382,
#        1205.2356231 , 3508.87818029, 2291.44174454, 2589.4969933 ,
#        3027.6890562 , 2553.13905166, 1103.06039456, 1341.93689735,
#         719.15552861, 2781.92054783, 2394.60518351, 2154.99277569,
#        1573.69015474, 3508.87818029, 2479.97457504,  772.71701059,
#        3698.60394179,  824.96700321, 1573.69015474, 1329.03475162,
#        2479.97457504,  731.74610066, 1573.69015474, 1435.1559591 ,
#        1811.41446475, 1668.23260541, 3451.94913577, 2599.68532357,
#         992.81827657, 2710.88090831, 1283.05034334, 3698.60394179,
#        2335.05378739, 1356.64643441, 3191.03792753, 2473.09141603,
#        1564.26151074, 3269.73194835, 1356.91134822, 1493.61977974,
predict(x_test))
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 훈련 세트의 정확도 : 0.9256
# 테스트 세트의 정확도 : 0.8942
# 경사부스팅의 오차: 213.8481

# %% [markdown]
# ## 하이퍼 파라미터 튜닝

# %% [markdown]
# ### n_estimators 조절

# %%
n_estimators = [100, 500, 1000] # weak learner의 개수. 개수가 많을수록 일정 수준까지는 좋아지지만 수행 시간이 오래 걸림
#learning_rate = [0.1, 0.5, 1] # (0.1)GBM이 학습을 진행할 때마다 적용하는 학습률. 0~1. 
#max_depth = [1, 2, 3, 4] # (3)트리의 최대 깊이. 깊이가 깊어지면 과적합이 될 수 있으므로 적절히 제어 필요.
#min_samples_leaf = [5, 10, 15] # (1)리프노드가 되기 위한 최소한의 샘플 데이터 수. 불균형 데이터의 경우 특정 클래스 데이터가 극도로 덕을 수 있으므로 작은 값으로 설정이 필요
#min_samples_split = [2, 5, 10] # (2)노드를 분할하기 위한 최소한의 샘플 데이터 수.

param_grid = {'n_estimators' : n_estimators}
              #'learning_rate' : learning_rate,
              #'max_depth' : max_depth,
              #'min_samples_leaf' : min_samples_leaf,
              #'min_samples_split' : min_samples_split}

# %%
gb = GridSearchCV(GradientBoostingRegressor(loss= 'huber'), #gridSearchcv 최적의 파라미터를 찾는 함수 
                  param_grid, cv=3, return_train_score=True)

# %%
param_grid
# Out:
# {'n_estimators': [100, 500, 1000]}

# %%
gb.fit(x_train, y_prime)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={'n_estimators': [100, 500, 1000]},
#              return_train_score=True)

# %%
print('최적 하이퍼 파라미터: ', gb.best_params_)
print('훈련 세트의 정확도 : {:.4f} '. format(gb.score(x_train, y_prime)))
print('테스트 세트의 정확도 : {:.4f} '.format(gb.score(x_test, y_test_prime)))

# MAE : 평균오차절대값
mae_pred =  mean_absolute_error(y_test_prime, gb.predict(x_test))
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 최적 하이퍼 파라미터:  {'n_estimators': 500}
# 훈련 세트의 정확도 : 0.9492
# 테스트 세트의 정확도 : 0.9095
# 경사부스팅의 오차: 194.9255

# %% [markdown]
# ### learning_rate 조절

# %%
n_estimators = [500] # weak learner의 개수. 개수가 많을수록 일정 수준까지는 좋아지지만 수행 시간이 오래 걸림
learning_rate = [0.1, 0.5, 1] # (0.1)GBM이 학습을 진행할 때마다 적용하는 학습률. 0~1. 
#max_depth = [1, 2, 3, 4] # (3)트리의 최대 깊이. 깊이가 깊어지면 과적합이 될 수 있으므로 적절히 제어 필요.
#min_samples_leaf = [5, 10, 15] # (1)리프노드가 되기 위한 최소한의 샘플 데이터 수. 불균형 데이터의 경우 특정 클래스 데이터가 극도로 덕을 수 있으므로 작은 값으로 설정이 필요
#min_samples_split = [2, 5, 10] # (2)노드를 분할하기 위한 최소한의 샘플 데이터 수. 

param_grid = {'n_estimators' : n_estimators,
              'learning_rate' : learning_rate}
              #'max_depth' : max_depth,
              #'min_samples_leaf' : min_samples_leaf,
              #'min_samples_split' : min_samples_split}

# %%
param_grid
# Out:
# {'n_estimators': [500], 'learning_rate': [0.1, 0.5, 1]}

# %%
gb_2 = GridSearchCV(GradientBoostingRegressor(loss= 'huber'),
                  param_grid, cv=3, return_train_score=True)

# %%
gb_2.fit(x_train, y_prime)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={'learning_rate': [0.1, 0.5, 1], 'n_estimators': [500]},
#              return_train_score=True)

# %%
print('최적 하이퍼 파라미터: ', gb_2.best_params_)
print('훈련 세트의 정확도 : {:.4f} '. format(gb_2.score(x_train, y_prime)))
print('테스트 세트의 정확도 : {:.4f} '.  format(gb_2.score(x_test, y_test_prime))) 

# MAE : 평균오차절대값
mae_pred =  mean_absolute_error(y_test_prime, gb_2.predict(x_test))
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 최적 하이퍼 파라미터:  {'learning_rate': 0.1, 'n_estimators': 500}
# 훈련 세트의 정확도 : 0.9497
# 테스트 세트의 정확도 : 0.9102
# 경사부스팅의 오차: 194.7761

# %% [markdown]
# ### max_depth 조절

# %%
n_estimators = [500] # weak learner의 개수. 개수가 많을수록 일정 수준까지는 좋아지지만 수행 시간이 오래 걸림
learning_rate = [0.1] # (0.1)GBM이 학습을 진행할 때마다 적용하는 학습률. 0~1. 
max_depth = [1, 2, 3, 4] # (3)트리의 최대 깊이. 깊이가 깊어지면 과적합이 될 수 있으므로 적절히 제어 필요.
#min_samples_leaf = [5, 10, 15] # (1)리프노드가 되기 위한 최소한의 샘플 데이터 수. 불균형 데이터의 경우 특정 클래스 데이터가 극도로 덕을 수 있으므로 작은 값으로 설정이 필요
#min_samples_split = [2, 5, 10] # (2)노드를 분할하기 위한 최소한의 샘플 데이터 수.

param_grid = {'n_estimators' : n_estimators,
              'learning_rate' : learning_rate,
              'max_depth' : max_depth}
              #'min_samples_leaf' : min_samples_leaf,
              #'min_samples_split' : min_samples_split}

# %%
param_grid
# Out:
# {'n_estimators': [500], 'learning_rate': [0.1], 'max_depth': [1, 2, 3, 4]}

# %%
gb_3 = GridSearchCV(GradientBoostingRegressor(loss= 'huber'),
                  param_grid, cv=3, return_train_score=True)

# %%
gb_3.fit(x_train, y_prime)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={'learning_rate': [0.1], 'max_depth': [1, 2, 3, 4],
#                          'n_estimators': [500]},
#              return_train_score=True)

# %%
print('최적 하이퍼 파라미터: ', gb_3.best_params_)
print('훈련 세트의 정확도 : {:.4f} '. format(gb_3.score(x_train, y_prime)))
print('테스트 세트의 정확도 : {:.4f} '.  format(gb_3.score(x_test, y_test_prime)))

# MAE : 평균오차절대값
mae_pred =  mean_absolute_error(y_test_prime, gb_3.predict(x_test))
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 최적 하이퍼 파라미터:  {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 500}
# 훈련 세트의 정확도 : 0.9398
# 테스트 세트의 정확도 : 0.9098
# 경사부스팅의 오차: 195.2746

# %% [markdown]
# ### min_samples_leaf 조절

# %%
n_estimators = [500] # weak learner의 개수. 개수가 많을수록 일정 수준까지는 좋아지지만 수행 시간이 오래 걸림
learning_rate = [0.1] # (0.1)GBM이 학습을 진행할 때마다 적용하는 학습률. 0~1. 
max_depth = [2] # (3)트리의 최대 깊이. 깊이가 깊어지면 과적합이 될 수 있으므로 적절히 제어 필요.
min_samples_leaf = [5, 10, 15] # (1)리프노드가 되기 위한 최소한의 샘플 데이터 수. 불균형 데이터의 경우 특정 클래스 데이터가 극도로 덕을 수 있으므로 작은 값으로 설정이 필요
#min_samples_split = [2, 5, 10] # (2)노드를 분할하기 위한 최소한의 샘플 데이터 수.

param_grid = {'n_estimators' : n_estimators,
              'learning_rate' : learning_rate,
              'max_depth' : max_depth,
              'min_samples_leaf' : min_samples_leaf}
              #'min_samples_split' : min_samples_split}

# %%
param_grid
# Out:
# {'n_estimators': [500],
#  'learning_rate': [0.1],
#  'max_depth': [2],
#  'min_samples_leaf': [5, 10, 15]}

# %%
gb_4 = GridSearchCV(GradientBoostingRegressor(loss= 'huber'),
                  param_grid, cv=3, return_train_score=True)

# %%
gb_4.fit(x_train, y_prime)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={'learning_rate': [0.1], 'max_depth': [2],
#                          'min_samples_leaf': [5, 10, 15],
#                          'n_estimators': [500]},
#              return_train_score=True)

# %%
print('최적 하이퍼 파라미터: ', gb_4.best_params_)
print('훈련 세트의 정확도 : {:.4f} '. format(gb_4.score(x_train, y_prime)))
print('테스트 세트의 정확도 : {:.4f} '. format(gb_4.score(x_test, y_test_prime))) 

# MAE : 평균오차절대값
mae_pred =  mean_absolute_error(y_test_prime, gb_4.predict(x_test))
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 최적 하이퍼 파라미터:  {'learning_rate': 0.1, 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 500}
# 훈련 세트의 정확도 : 0.9288
# 테스트 세트의 정확도 : 0.9075
# 경사부스팅의 오차: 197.5223

# %% [markdown]
# ### min_samples_split 조절

# %%
n_estimators = [500] # weak learner의 개수. 개수가 많을수록 일정 수준까지는 좋아지지만 수행 시간이 오래 걸림
learning_rate = [0.1] # (0.1)GBM이 학습을 진행할 때마다 적용하는 학습률. 0~1. 
max_depth = [2] # (3)트리의 최대 깊이. 깊이가 깊어지면 과적합이 될 수 있으므로 적절히 제어 필요.
min_samples_leaf = [5] # (1)리프노드가 되기 위한 최소한의 샘플 데이터 수. 불균형 데이터의 경우 특정 클래스 데이터가 극도로 덕을 수 있으므로 작은 값으로 설정이 필요
min_samples_split = [2, 5, 10] # (2)노드를 분할하기 위한 최소한의 샘플 데이터 수.

param_grid = {'n_estimators' : n_estimators,
              'learning_rate' : learning_rate,
              'max_depth' : max_depth,
              'min_samples_leaf' : min_samples_leaf,
              'min_samples_split' : min_samples_split}

# %%
param_grid
# Out:
# {'n_estimators': [500],
#  'learning_rate': [0.1],
#  'max_depth': [2],
#  'min_samples_leaf': [5],
#  'min_samples_split': [2, 5, 10]}

# %%
gb_5 = GridSearchCV(GradientBoostingRegressor(loss= 'huber'),
                  param_grid, cv=3, return_train_score=True)

# %%
gb_5.fit(x_train, y_prime)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={'learning_rate': [0.1], 'max_depth': [2],
#                          'min_samples_leaf': [5],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [500]},
#              return_train_score=True)

# %%
print('최적 하이퍼 파라미터: ', gb_5.best_params_)
print('훈련 세트의 정확도 : {:.4f} '. format(gb_5.score(x_train, y_prime)))
print('테스트 세트의 정확도 : {:.4f} '. format(gb_5.score(x_test, y_test_prime)))

# MAE : 평균오차절대값
mae_pred =  mean_absolute_error(y_test_prime, gb_5.predict(x_test))
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 최적 하이퍼 파라미터:  {'learning_rate': 0.1, 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 500}
# 훈련 세트의 정확도 : 0.9288
# 테스트 세트의 정확도 : 0.9081
# 경사부스팅의 오차: 197.1719

# %% [markdown]
# ### 최종 파라미터

# %%
n_estimators = [100] # weak learner의 개수. 개수가 많을수록 일정 수준까지는 좋아지지만 수행 시간이 오래 걸림
learning_rate = [0.1] # (0.1)GBM이 학습을 진행할 때마다 적용하는 학습률. 0~1. 
max_depth = [2] # (3)트리의 최대 깊이. 깊이가 깊어지면 과적합이 될 수 있으므로 적절히 제어 필요.
min_samples_leaf = [5] # (1)리프노드가 되기 위한 최소한의 샘플 데이터 수. 불균형 데이터의 경우 특정 클래스 데이터가 극도로 덕을 수 있으므로 작은 값으로 설정이 필요
min_samples_split = [10] # (2)노드를 분할하기 위한 최소한의 샘플 데이터 수.

param_grid = {'n_estimators' : n_estimators,
              'learning_rate' : learning_rate,
              'max_depth' : max_depth,
              'min_samples_leaf' : min_samples_leaf,
              'min_samples_split' : min_samples_split}

# %%
param_grid
# Out:
# {'n_estimators': [100],
#  'learning_rate': [0.1],
#  'max_depth': [2],
#  'min_samples_leaf': [5],
#  'min_samples_split': [10]}

# %%
gb_6 = GridSearchCV(GradientBoostingRegressor(loss= 'huber'),
                  param_grid, cv=3, return_train_score=True)

# %%
gb_6.fit(x_train, y_prime)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={'learning_rate': [0.1], 'max_depth': [2],
#                          'min_samples_leaf': [5], 'min_samples_split': [10],
#                          'n_estimators': [100]},
#              return_train_score=True)

# %%
print('최적 하이퍼 파라미터: ', gb_6.best_params_)
print('훈련 세트의 정확도 : {:.4f} '. format(gb_6.score(x_train, y_prime)))
print('테스트 세트의 정확도 : {:.4f} '. format(gb_6.score(x_test, y_test_prime))) 

# MAE : 평균오차절대값
mae_pred =  mean_absolute_error(y_test_prime, gb_6.predict(x_test))
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 최적 하이퍼 파라미터:  {'learning_rate': 0.1, 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 훈련 세트의 정확도 : 0.8967
# 테스트 세트의 정확도 : 0.8821
# 경사부스팅의 오차: 226.4737

# %% [markdown]
# # 저장

# %%
import joblib

joblib.__version__
# Out:
# '1.5.1'

# %%
joblib.dump( gb_6, 'car.model' )
# Out:
# ['car.model']

# %% [markdown]
# # pickle

# %%
import pickle

# %%
with open('car.pickle','wb') as f:
    pickle.dump(gb_6, f)

# %%
with open('car.pickle', 'rb') as f: 
    model = pickle.load(f)

# %%
model
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(loss='huber'),
#              param_grid={'learning_rate': [0.1], 'max_depth': [2],
#                          'min_samples_leaf': [5], 'min_samples_split': [10],
#                          'n_estimators': [100]},
#              return_train_score=True)

# %% [markdown]
# 현대, 2017년, 휘발유
# 아우디, 2014년, 휘발유
# 이거 두 개로 예측한 가격 좀 뽑아 줄 수 잇어?

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 62 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   price                             1310 non-null   int64
#  1   brand_hyundai                     1310 non-null   bool
#  2   model_grandeur                    1310 non-null   bool
#  3   model_grandeurHG                  1310 non-null   bool
#  4   model_grandeurHG_hybrid           1310 non-null   bool
#  5   model_grandeurTG                  1310 non-null   bool
#  6   model_grandeur_GN7                1310 non-null   bool
#  7   model_grandeur_IG                 1310 non-null   bool
#  8   model_grandeur_IG_hybrid          1310 non-null   bool
#  9   model_grandeur_hybrid_GN7         1310 non-null   bool
#  10  model_grandeur_new_luxury         1310 non-null   bool
#  11  model_new_grandeur                1310 non-null   bool
#  12  model_the_luxury_grandeur         1310 non-null   bool
#  13  model_the_new_grandeur_IG         1310 non-null   bool
#  14  model_the_new_grandeur_IG_hybrid  1310 non-null   bool
#  15  year_1992                         1310 non-null   bool
#  16  year_1994                         1310 non-null   bool
#  17  year_2006                         1310 non-null   bool
#  18  year_2007                         1310 non-null   bool
#  19  year_2008                         1310 non-null   bool
#  20  year_2009                         1310 non-null   bool
#  21  year_2010                         1310 non-null   bool
#  22  year_2011                         1310 non-null   bool
#  23  year_2012                         1310 non-null   bool
#  24  year_2013                         1310 non-null   bool
#  25  year_2014                         1310 non-null   bool
#  26  year_2015                         1310 non-null   bool
#  27  year_2016                         1310 non-null   bool
#  28  year_2017                         1310 non-null   bool
#  29  year_2018                         1310 non-null   bool
#  30  year_2019                         1310 non-null   bool
#  31  year_2020                         1310 non-null   bool
#  32  year_2021                         1310 non-null   bool
#  33  year_2022                         1310 non-null   bool
#  34  year_2023                         1310 non-null   bool
#  35  year_2024                         1310 non-null   bool
#  36  year_2025                         1310 non-null   bool
#  37  year_2026                         1310 non-null   bool
#  38  oilingtype_LPG                    1310 non-null   bool
#  39  oilingtype_diesel                 1310 non-null   bool
#  40  oilingtype_gasoline               1310 non-null   bool
#  41  oilingtype_hybrid                 1310 non-null   bool
#  42  mileage_0_10000                   1310 non-null   bool
#  43  mileage_10001_20000               1310 non-null   bool
#  44  mileage_20001_30000               1310 non-null   bool
#  45  mileage_30001_40000               1310 non-null   bool
#  46  mileage_40001_50000               1310 non-null   bool
#  47  mileage_50001_60000               1310 non-null   bool
#  48  mileage_60001_70000               1310 non-null   bool
#  49  mileage_70001_80000               1310 non-null   bool
#  50  mileage_80001_90000               1310 non-null   bool
#  51  mileage_90001_100000              1310 non-null   bool
#  52  mileage_100001_110000             1310 non-null   bool
#  53  mileage_110001_120000             1310 non-null   bool
#  54  mileage_120001_130000             1310 non-null   bool
#  55  mileage_130001_140000             1310 non-null   bool
#  56  mileage_140001_150000             1310 non-null   bool
#  57  mileage_150001_160000             1310 non-null   bool
#  58  mileage_160001_170000             1310 non-null   bool
#  59  mileage_170001_180000             1310 non-null   bool
#  60  mileage_180001_190000             1310 non-null   bool
#  61  mileage_190001_200000             1310 non-null   bool
# dtypes: bool(61), int64(1)
# memory usage: 88.4 KB

# %%
car1 = car.loc[car['brand_hyundai'] == 1]
car1
# Out:
#       price  brand_hyundai  model_grandeur  model_grandeurHG  \
# 0      1999           True           False             False
# 1      2489           True           False             False
# 2      2950           True           False             False
# 3      1540           True           False             False
# 4      2400           True           False             False
# ...     ...            ...             ...               ...
# 1305    550           True           False              True
# 1306    689           True           False              True
# 1307   1650           True           False             False
# 1308    800           True           False              True
# 1309   1470           True           False             False
#
#       model_grandeurHG_hybrid  model_grandeurTG  model_grandeur_GN7  \
# 0                       False             False               False
# 1                       False             False               False
# 2                       False             False                True
# 3                       False             False               False
# 4                       False             False               False
# ...                       ...               ...                 ...
# 1305                    False             False               False
# 1306                    False             False               False
# 1307                    False             False               False
# 1308                    False             False               False
# 1309                    False             False               False
#
#       model_grandeur_IG  model_grandeur_IG_hybrid  model_grandeur_hybrid_GN7  \
# 0                 False                     False                      False
# 1                 False                     False                      False
# 2                 False                     False                      False
# 3                 False                      True                      False
# 4                 False                     False                      False
# ...                 ...                       ...                        ...
# 1305              False                     False                      False
# 1306              False                     False                      False
# 1307               True                     False                      False
# 1308              False                     False                      False
# 1309               True                     False                      False
#
#       ...  mileage_100001_110000  mileage_110001_120000  \
# 0     ...                  False                   True
# 1     ...                  False                  False
# 2     ...                  False                  False
# 3     ...                  False                  False
# 4     ...                  False                  False
# ...   ...                    ...                    ...
# 1305  ...                  False                  False
# 1306  ...                  False                  False
# 1307  ...                  False                  False
# 1308  ...                  False                  False
# 1309  ...                  False                   True
#
#       mileage_120001_130000  mileage_130001_140000  mileage_140001_150000  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                      True                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 1305                  False                  False                   True
# 1306                  False                  False                  False
# 1307                  False                  False                  False
# 1308                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_150001_160000  mileage_160001_170000  mileage_170001_180000  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 1305                  False                  False                  False
# 1306                  False                  False                  False
# 1307                  False                  False                  False
# 1308                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_180001_190000  mileage_190001_200000
# 0                     False                  False
# 1                     False                  False
# 2                     False                  False
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 1305                  False                  False
# 1306                  False                  False
# 1307                  False                  False
# 1308                   True                  False
# 1309                  False                  False
#
# [1310 rows x 62 columns]

# %%
car2 = car1.loc[car1['year_2020'] == 1]
car2
# Out:
#       price  brand_hyundai  model_grandeur  model_grandeurHG  \
# 6      2690           True           False             False
# 11     2030           True           False             False
# 29     1750           True           False             False
# 31     2230           True           False             False
# 71     2909           True           False             False
# ...     ...            ...             ...               ...
# 1274   1750           True           False             False
# 1285   2230           True           False             False
# 1290   1480           True           False             False
# 1297   2500           True           False             False
# 1309   1470           True           False             False
#
#       model_grandeurHG_hybrid  model_grandeurTG  model_grandeur_GN7  \
# 6                       False             False               False
# 11                      False             False               False
# 29                      False             False               False
# 31                      False             False               False
# 71                      False             False               False
# ...                       ...               ...                 ...
# 1274                    False             False               False
# 1285                    False             False               False
# 1290                    False             False               False
# 1297                    False             False               False
# 1309                    False             False               False
#
#       model_grandeur_IG  model_grandeur_IG_hybrid  model_grandeur_hybrid_GN7  \
# 6                 False                     False                      False
# 11                False                      True                      False
# 29                False                      True                      False
# 31                False                     False                      False
# 71                False                     False                      False
# ...                 ...                       ...                        ...
# 1274              False                      True                      False
# 1285              False                     False                      False
# 1290               True                     False                      False
# 1297              False                      True                      False
# 1309               True                     False                      False
#
#       ...  mileage_100001_110000  mileage_110001_120000  \
# 6     ...                  False                  False
# 11    ...                  False                   True
# 29    ...                  False                  False
# 31    ...                  False                  False
# 71    ...                  False                  False
# ...   ...                    ...                    ...
# 1274  ...                  False                  False
# 1285  ...                  False                  False
# 1290  ...                  False                   True
# 1297  ...                  False                  False
# 1309  ...                  False                   True
#
#       mileage_120001_130000  mileage_130001_140000  mileage_140001_150000  \
# 6                     False                  False                  False
# 11                    False                  False                  False
# 29                    False                   True                  False
# 31                    False                  False                  False
# 71                    False                  False                  False
# ...                     ...                    ...                    ...
# 1274                  False                  False                   True
# 1285                  False                  False                  False
# 1290                  False                  False                  False
# 1297                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_150001_160000  mileage_160001_170000  mileage_170001_180000  \
# 6                     False                  False                  False
# 11                    False                  False                  False
# 29                    False                  False                  False
# 31                    False                  False                  False
# 71                    False                  False                  False
# ...                     ...                    ...                    ...
# 1274                  False                  False                  False
# 1285                  False                  False                  False
# 1290                  False                  False                  False
# 1297                  False                  False                  False
# 1309                  False                  False                  False
#
#       mileage_180001_190000  mileage_190001_200000
# 6                     False                  False
# 11                    False                  False
# 29                    False                  False
# 31                    False                  False
# 71                    False                  False
# ...                     ...                    ...
# 1274                  False                  False
# 1285                  False                  False
# 1290                  False                  False
# 1297                  False                  False
# 1309                  False                  False
#
# [85 rows x 62 columns]

# %%
car3 = car2.loc[car2['oilingtype_gasoline'] == 1]
car3
# Out:
#       price  brand_hyundai  model_grandeur  model_grandeurHG  \
# 6      2690           True           False             False
# 71     2909           True           False             False
# 73     1570           True           False             False
# 109    1532           True           False             False
# 117    1630           True           False             False
# 141    1880           True           False             False
# 150    2471           True           False             False
# 170    1845           True           False             False
# 175    1690           True           False             False
# 192    2090           True           False             False
# 204    1480           True           False             False
# 231    1580           True           False             False
# 239    2250           True           False             False
# 250    1480           True           False             False
# 269    1629           True           False             False
# 308    1730           True           False             False
# 320    1249           True           False             False
# 353    1790           True           False             False
# 364    1950           True           False             False
# 377    1790           True           False             False
# 389    1430           True           False             False
# 398    1895           True           False             False
# 421    1590           True           False             False
# 429    1299           True           False             False
# 545    1599           True           False             False
# 547    1650           True           False             False
# 565    1390           True           False             False
# 582    1599           True           False             False
# 657    1980           True           False             False
# 671    2450           True           False             False
# 699    1550           True           False             False
# 710    1300           True           False             False
# 717    1840           True           False             False
# 742    2300           True           False             False
# 785    2400           True           False             False
# 924    1620           True           False             False
# 946    1660           True           False             False
# 973    1450           True           False             False
# 997    1780           True           False             False
# 1012   1780           True           False             False
# 1045   2150           True           False             False
# 1069   1630           True           False             False
# 1097   1450           True           False             False
# 1188   1730           True           False             False
# 1208   1800           True           False             False
# 1216   1730           True           False             False
# 1221   1350           True           False             False
# 1232   1880           True           False             False
# 1240   1690           True           False             False
# 1247   1770           True           False             False
# 1250   1750           True           False             False
# 1265   1199           True           False             False
# 1290   1480           True           False             False
# 1309   1470           True           False             False
#
#       model_grandeurHG_hybrid  model_grandeurTG  model_grandeur_GN7  \
# 6                       False             False               False
# 71                      False             False               False
# 73                      False             False               False
# 109                     False             False               False
# 117                     False             False               False
# 141                     False             False               False
# 150                     False             False               False
# 170                     False             False               False
# 175                     False             False               False
# 192                     False             False               False
# 204                     False             False               False
# 231                     False             False               False
# 239                     False             False               False
# 250                     False             False               False
# 269                     False             False               False
# 308                     False             False               False
# 320                     False             False               False
# 353                     False             False               False
# 364                     False             False               False
# 377                     False             False               False
# 389                     False             False               False
# 398                     False             False               False
# 421                     False             False               False
# 429                     False             False               False
# 545                     False             False               False
# 547                     False             False               False
# 565                     False             False               False
# 582                     False             False               False
# 657                     False             False               False
# 671                     False             False               False
# 699                     False             False               False
# 710                     False             False               False
# 717                     False             False               False
# 742                     False             False               False
# 785                     False             False               False
# 924                     False             False               False
# 946                     False             False               False
# 973                     False             False               False
# 997                     False             False               False
# 1012                    False             False               False
# 1045                    False             False               False
# 1069                    False             False               False
# 1097                    False             False               False
# 1188                    False             False               False
# 1208                    False             False               False
# 1216                    False             False               False
# 1221                    False             False               False
# 1232                    False             False               False
# 1240                    False             False               False
# 1247                    False             False               False
# 1250                    False             False               False
# 1265                    False             False               False
# 1290                    False             False               False
# 1309                    False             False               False
#
#       model_grandeur_IG  model_grandeur_IG_hybrid  model_grandeur_hybrid_GN7  \
#
# 785                   False                  False
# 924                   False                  False
# 946                   False                  False
# 973                   False                  False
# 997                   False                  False
# 1012                  False                  False
# 1045                  False                  False
# 1069                  False                  False
# 1097                  False                  False
# 1188                  False                  False
# 1208                  False                  False
# 1216                  False                  False
# 1221                  False                  False
# 1232                  False                  False
# 1240                  False                  False
# 1247                  False                  False
# 1250                  False                  False
# 1265                  False                  False
# 1290                  False                  False
# 1309                  False                  False
#
# [54 rows x 62 columns]

# %%
car4 = car3.loc[car3['mileage_20001_30000'] == 1]
car4
# Out:
#      price  brand_hyundai  model_grandeur  model_grandeurHG  \
# 6     2690           True           False             False
# 997   1780           True           False             False
#
#      model_grandeurHG_hybrid  model_grandeurTG  model_grandeur_GN7  \
# 6                      False             False               False
# 997                    False             False               False
#
#      model_grandeur_IG  model_grandeur_IG_hybrid  model_grandeur_hybrid_GN7  \
# 6                False                     False                      False
# 997               True                     False                      False
#
#      ...  mileage_100001_110000  mileage_110001_120000  mileage_120001_130000  \
# 6    ...                  False                  False                  False
# 997  ...                  False                  False                  False
#
#      mileage_130001_140000  mileage_140001_150000  mileage_150001_160000  \
# 6                    False                  False                  False
# 997                  False                  False                  False
#
#      mileage_160001_170000  mileage_170001_180000  mileage_180001_190000  \
# 6                    False                  False                  False
# 997                  False                  False                  False
#
#      mileage_190001_200000
# 6                    False
# 997                  False
#
# [2 rows x 62 columns]

# %%
x = car4.drop("price", axis =1)
y = car4["price"]

# %%
x
# Out:
#      brand_hyundai  model_grandeur  model_grandeurHG  model_grandeurHG_hybrid  \
# 6             True           False             False                    False
# 997           True           False             False                    False
#
#      model_grandeurTG  model_grandeur_GN7  model_grandeur_IG  \
# 6               False               False              False
# 997             False               False               True
#
#      model_grandeur_IG_hybrid  model_grandeur_hybrid_GN7  \
# 6                       False                      False
# 997                     False                      False
#
#      model_grandeur_new_luxury  ...  mileage_100001_110000  \
# 6                        False  ...                  False
# 997                      False  ...                  False
#
#      mileage_110001_120000  mileage_120001_130000  mileage_130001_140000  \
# 6                    False                  False                  False
# 997                  False                  False                  False
#
#      mileage_140001_150000  mileage_150001_160000  mileage_160001_170000  \
# 6                    False                  False                  False
# 997                  False                  False                  False
#
#      mileage_170001_180000  mileage_180001_190000  mileage_190001_200000
# 6                    False                  False                  False
# 997                  False                  False                  False
#
# [2 rows x 61 columns]

# %%
y
# Out:
# 6      2690
# 997    1780
# Name: price, dtype: int64

# %%
y_pred = model.predict(x) #예축값 
print(y_pred)

# 최소값
min_val = np.min(y_pred)

# 최대값
max_val = np.max(y_pred)

# 평균값
mean_val = np.mean(y_pred)

print(f"최소값: {min_val:.0f}")
print(f"최대값: {max_val:.0f}")
print(f"평균값: {mean_val:.0f}")
# Out:
# [2518.38575126 1954.92908518]
# 최소값: 1955
# 최대값: 2518
# 평균값: 2237

# %%
print('테스트 세트의 정확도 : {:.4f} '. format(model.score(x, y)))

# MAE : 평균오차절대값
mae_pred =  mean_absolute_error(y, y_pred)
print('경사부스팅의 오차: {:.4f}'.format(mae_pred))
# Out:
# 테스트 세트의 정확도 : 0.8550
# 경사부스팅의 오차: 173.2717
